# %% [markdown]
# <a href="https://colab.research.google.com/github/pranav-Karthick/AIML-Training/blob/main/Multinomial_Naive_Bayes_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/content/combined_sentiment_data.csv")

# %%
X = df['sentence']
y = df['sentiment']

# %%
vectorizer = CountVectorizer(stop_words='english')
X_vec = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.2, random_state=42)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8308157099697885
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.83      0.84      0.83       334
#     positive       0.83      0.83      0.83       328
#
#     accuracy                           0.83       662
#    macro avg       0.83      0.83      0.83       662
# weighted avg       0.83      0.83      0.83       662

# %%
cm = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots()
cax = ax.matshow(cm)
fig.colorbar(cax)

for (i, j), val in np.ndenumerate(cm):
    ax.text(j, i, f"{val}", ha='center', va='center')

ax.set_xlabel("Predicted")
ax.set_ylabel("Actual")
ax.set_title("Confusion Matrix - Multinomial Naive Bayes")

plt.show()
